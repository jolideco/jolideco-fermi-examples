# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/Users/adonath/software/mambaforge/envs/jolideco-fermi-examples/lib/python3.9/site-packages', '/Users/adonath/Library/Caches/snakemake/snakemake/source-cache/runtime-cache/tmpfkdjte4q/file/Users/adonath/github/jolideco/jolideco-fermi-examples/workflow/rules/../notebooks', '/Users/adonath/github/jolideco/jolideco-fermi-examples/workflow/rules/../notebooks']); import pickle; snakemake = pickle.loads(b"\x80\x04\x95\x18\x0b\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c_results/vela-junior-above-10GeV-data/jolideco/input/vela-junior-above-10GeV-data-psf0-maps.fits\x94\x8c_results/vela-junior-above-10GeV-data/jolideco/input/vela-junior-above-10GeV-data-psf1-maps.fits\x94\x8c_results/vela-junior-above-10GeV-data/jolideco/input/vela-junior-above-10GeV-data-psf2-maps.fits\x94\x8c_results/vela-junior-above-10GeV-data/jolideco/input/vela-junior-above-10GeV-data-psf3-maps.fits\x94e}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x13\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x19)}\x94\x8c\x05_name\x94h\x13sNt\x94bh\x14h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x14sNt\x94bub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c_results/vela-junior-above-10GeV-data/jolideco/vela-junior-above-10GeV-data-result-jolideco.fits\x94\x8cUresults/vela-junior-above-10GeV-data/jolideco/vela-junior-above-10GeV-data-npred.fits\x94e}\x94(h\x0f}\x94(\x8c\x18filename_jolideco_result\x94K\x00N\x86\x94\x8c\x16filename_npred_stacked\x94K\x01N\x86\x94uh\x11]\x94(h\x13h\x14eh\x13h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x13sNt\x94bh\x14h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x14sNt\x94bh+h'h-h(ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0f}\x94h\x11]\x94(h\x13h\x14eh\x13h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x13sNt\x94bh\x14h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x14sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\x1cvela-junior-above-10GeV-data\x94a}\x94(h\x0f}\x94\x8c\x0bconfig_name\x94K\x00N\x86\x94sh\x11]\x94(h\x13h\x14eh\x13h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x13sNt\x94bh\x14h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x14sNt\x94b\x8c\x0bconfig_name\x94hKub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c0/var/folders/bt/7xysb53d3vj7m_snm7wt9jhc0000gp/T\x94e}\x94(h\x0f}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x11]\x94(h\x13h\x14eh\x13h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x13sNt\x94bh\x14h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x14sNt\x94bhbK\x01hdK\x01hfh_ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cYresults/vela-junior-above-10GeV-data/jolideco/vela-junior-above-10GeV-data-jolideco.ipynb\x94a}\x94(h\x0f}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x11]\x94(h\x13h\x14eh\x13h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x13sNt\x94bh\x14h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x14sNt\x94bhxhuub\x8c\x06config\x94}\x94\x8c\x0efermi-lat-data\x94}\x94(\x8c\x04name\x94\x8c\x1cvela-junior-above-10GeV-data\x94\x8c\x06scfile\x94\x8c&data/L230210105554348FF7BE69_SC00.fits\x94\x8c\x0bevent_types\x94]\x94(\x8c\x04psf0\x94\x8c\x04psf1\x94\x8c\x04psf2\x94\x8c\x04psf3\x94e\x8c\nfermitools\x94}\x94(\x8c\x08gtselect\x94}\x94(\x8c\x02ra\x94\x8c\t08h52m00s\x94\x8c\x03dec\x94\x8c\x13-46d19m58.80065918s\x94\x8c\x03rad\x94\x8c\x055 deg\x94\x8c\x04tmin\x94\x8c\x132008-08-04 15:43:36\x94\x8c\x04tmax\x94\x8c\x132023-02-10 21:46:14\x94\x8c\x04emin\x94\x8c\x055 GeV\x94\x8c\x04emax\x94\x8c\x052 TeV\x94\x8c\x04zmax\x94\x8c\x07105 deg\x94\x8c\x07evclass\x94K\x80u\x8c\x08gtmktime\x94}\x94(\x8c\x06filter\x94\x8c '(DATA_QUAL>0)&&(LAT_CONFIG==1)'\x94\x8c\x06roicut\x94\x8c\x03yes\x94u\x8c\x05gtbin\x94}\x94(\x8c\talgorithm\x94\x8c\x05CCUBE\x94\x8c\x05nxpix\x94M^\x01\x8c\x05nypix\x94M^\x01\x8c\x05binsz\x94G?\x94z\xe1G\xae\x14{\x8c\x04xref\x94G@p\xa4$e'L\x1f\x8c\x04yref\x94G\xbf\xf3\x83\xab\r_d\x14\x8c\x04proj\x94\x8c\x03CAR\x94\x8c\x08coordsys\x94\x8c\x03GAL\x94\x8c\x07ebinalg\x94\x8c\x03LOG\x94\x8c\x08enumbins\x94K\x0b\x8c\x07axisrot\x94K\x00\x8c\x04emin\x94h\xa0\x8c\x04emax\x94h\xa2u\x8c\x08gtltcube\x94}\x94(\x8c\tdcostheta\x94G?\x99\x99\x99\x99\x99\x99\x9a\x8c\x05binsz\x94G?\xf0\x00\x00\x00\x00\x00\x00\x8c\x04tmin\x94h\x9c\x8c\x04tmax\x94h\x9e\x8c\x04zmax\x94h\xa4u\x8c\ngtexpcube2\x94}\x94(\x8c\x08coordsys\x94h\xb8\x8c\x05binsz\x94G?\x94z\xe1G\xae\x14{\x8c\x05nxpix\x94M^\x01\x8c\x05nypix\x94M^\x01\x8c\x04xref\x94G@p\xa4$e'L\x1f\x8c\x04yref\x94G\xbf\xf3\x83\xab\r_d\x14\x8c\x04proj\x94h\xb6\x8c\x07ebinalg\x94h\xba\x8c\x04cmap\x94\x8c\x04none\x94\x8c\x04emin\x94\x8c\x055 GeV\x94\x8c\x04emax\x94\x8c\x052 TeV\x94\x8c\x08enumbins\x94K\x10\x8c\x07axisrot\x94K\x00\x8c\x07bincalc\x94\x8c\x04EDGE\x94u\x8c\x05gtpsf\x94}\x94(\x8c\x08thetamax\x94K\n\x8c\x06ntheta\x94M,\x01\x8c\x02ra\x94h\x96\x8c\x03dec\x94h\x98\x8c\x04emin\x94h\xd3\x8c\x04emax\x94h\xd5\x8c\tnenergies\x94K\x11uuus\x8c\x04rule\x94\x8c\x0crun_jolideco\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cR/Users/adonath/github/jolideco/jolideco-fermi-examples/workflow/rules/../notebooks\x94ub."); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/Users/adonath/github/jolideco/jolideco-fermi-examples');
######## snakemake preamble end #########

# %% [markdown]
# # Jolideco Analysis of Fermi-LAT data of Vela Junior

# %%
import numpy as np
from pathlib import Path
from matplotlib import pyplot as plt
import matplotlib as mpl
from astropy.visualization import simple_norm
from astropy import units as u
from jolideco.core import MAPDeconvolver
from jolideco.models import (
    SpatialFluxComponent,
    FluxComponents,
    NPredModels,
    NPredCalibration,
    NPredCalibrations
)
from jolideco.priors import GMMPatchPrior, GaussianMixtureModel
from jolideco.utils.norms import IdentityImageNorm
from itertools import zip_longest
from regions import CircleSkyRegion
from gammapy.maps import Maps, WcsGeom, Map

# %%
# for vscode dark theme
# plt.style.use('dark_background')
# mpl.rcParams['figure.facecolor'] = '#25292E'

# %%
if "snakemake" in globals():
    filenames = [Path(_) for _ in snakemake.input]
    filename_jolideco_result = Path(snakemake.output.filename_jolideco_result)
    filename_npred_stacked = Path(snakemake.output.filename_npred_stacked)
else:
    config_name = "vela-junior-above-10GeV-data"
    PATH_BASE = Path(f"../../results/{config_name}/")
    filenames = (PATH_BASE / "input").glob("*.fits")
    filename_jolideco_result = PATH_BASE / f"{config_name}-result-jolideco.fits"
    filename_npred_stacked = PATH_BASE / f"{config_name}-npred.fits"

# %%
datasets = {}

for filename in filenames:
    maps = Maps.read(filename)
    datasets[filename.stem.replace("-maps", "")] = maps

# %% [markdown]
# ## Counts

# %%
wcs = datasets["vela-junior-above-10GeV-data-psf0"]["counts"].geom.wcs

fig, axes = plt.subplots(
    ncols=2,
    nrows=2,
    subplot_kw={"projection": wcs},
    figsize=(12, 12)
)

for ax, (name, maps) in zip(axes.flat, datasets.items()):
    counts = maps["counts"].sum_over_axes()
    counts.plot(ax=ax, cmap="viridis", add_cbar=True)
    ax.set_title(f"{name}")

# %% [markdown]
# ## Background

# %%
fig, axes = plt.subplots(
    ncols=2,
    nrows=2,
    subplot_kw={"projection": wcs},
    figsize=(12, 12)
)

for ax, (name, maps) in zip(axes.flat, datasets.items()):
    background = maps["background"].sum_over_axes()
    background.plot(ax=ax, cmap="viridis", add_cbar=True, stretch="log")
    ax.set_title(f"{name}")

# %% [markdown]
# ## PSF

# %%
wcs = datasets["vela-junior-above-10GeV-data-psf0"]["psf"].geom.wcs

fig, axes = plt.subplots(
    ncols=2,
    nrows=2,
    subplot_kw={"projection": wcs},
    figsize=(12, 12)
)

for ax, (name, maps) in zip(axes.flat, datasets.items()):
    psf = maps["psf"].sum_over_axes()
    psf.plot(ax=ax, cmap="viridis", add_cbar=True, stretch="log")
    ax.set_title(f"{name}")

# %%
def to_jolideco_dataset(maps, dtype=np.float32):
    """Convert Gammapy maps to Jolideco dataset."""
    return {
        "counts": maps["counts"].data[0].astype(dtype),
        "background": maps["background"].data[0].astype(dtype),
        "psf": {"vela-junior": maps["psf"].data[0].astype(dtype)},
        "exposure": maps["exposure"].data[0].astype(dtype),
    }

# %%
datasets_jolideco = {name: to_jolideco_dataset(maps) for name, maps in datasets.items()}

# %% [markdown]
# ## Run Jolideco

# %%
gmm = GaussianMixtureModel.from_registry("chandra-snrs-v0.1")
gmm.stride = 4
print(gmm)
# Out:
# GaussianMixtureModel
# --------------------
#
#   type                  : chandra-snrs-v0.1

# %%
gmm.plot_mean_images(ncols=16, figsize=(12, 8))

# %%
patch_prior = GMMPatchPrior(
    gmm=gmm,
    cycle_spin=True,
    stride=4,
    norm=IdentityImageNorm()
)


shape = datasets_jolideco["vela-junior-above-10GeV-data-psf1"]["counts"].shape
flux_init = np.random.normal(loc=0.1, scale=0.01, size=shape).astype(np.float32)

component = SpatialFluxComponent.from_numpy(
    flux=flux_init,
    prior=patch_prior,
    use_log_flux=True,
    upsampling_factor=1,
)


components = FluxComponents()
components["vela-junior"] = component

print(components)
# Out:
# FluxComponents
# --------------
#
#   vela-junior           :
#
#     use_log_flux        : True
#     upsampling_factor   : 1
#     frozen              : False
#     prior               :
#
#       type              : gmm-patches
#       stride            : 4
#       cycle_spin        : True
#       cycle_spin_subpix : False
#       jitter            : False
#       gmm               :
#
#         type            : chandra-snrs-v0.1
#
#       norm              :
#
#         type            : identity
#
#       patch_norm        :
#
#         type            : std-subtract-mean
#
#       device            : cpu

# %%
calibrations = NPredCalibrations()

for name, value in zip(datasets, [0.5, 1.2, 1.2, 1.2]):
    calibration = NPredCalibration(background_norm=value, frozen=False)
    calibrations[name] = calibration

print(calibrations)
# Out:
# NPredCalibrations
# -----------------
#
#   vela-junior-above-10GeV-data-psf0:
#
#     shift_x             : 0.000
#     shift_y             : 0.000
#     background_norm     : 0.500
#     frozen              : False
#
#   vela-junior-above-10GeV-data-psf1:
#
#     shift_x             : 0.000
#     shift_y             : 0.000
#     background_norm     : 1.200
#     frozen              : False
#
#   vela-junior-above-10GeV-data-psf2:
#
#     shift_x             : 0.000
#     shift_y             : 0.000
#     background_norm     : 1.200
#     frozen              : False
#
#   vela-junior-above-10GeV-data-psf3:
#
#     shift_x             : 0.000
#     shift_y             : 0.000
#     background_norm     : 1.200
#     frozen              : False

# %%
deconvolve = MAPDeconvolver(n_epochs=500, learning_rate=0.1)
print(deconvolve)
# Out:
# MAPDeconvolver
# --------------
#
#   n_epochs              : 500
#   beta                  : 1
#   learning_rate         : 0.100
#   compute_error         : False
#   stop_early            : False
#   stop_early_n_average  : 10
#   display_progress      : True
#   device                : cpu

# %%
result = deconvolve.run(
    datasets=datasets_jolideco,
    components=components,
    calibrations=calibrations
)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# /Users/adonath/software/mambaforge/envs/jolideco-fermi-examples/lib/python3.9/site-packages/torch/nn/functional.py:4289: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# /Users/adonath/software/mambaforge/envs/jolideco-fermi-examples/lib/python3.9/site-packages/torch/nn/functional.py:4289: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(

# %%
plt.figure(figsize=(12, 8))
result.plot_trace_loss()
# Out:
# <Axes: xlabel='# Iteration', ylabel='Loss value'>

# %% [markdown]
# ## Results

# %%
counts = np.sum([_["counts"] for _ in datasets_jolideco.values()], axis=0)

fig, axes = plt.subplots(
    ncols=2,
    subplot_kw={"projection": wcs},
    figsize=(14, 6)
)

norm_asinh = simple_norm(
    counts,
    min_cut=0.1,
    max_cut=0.5,
    stretch="power",
    power=1.,
)


norm = simple_norm(
    counts,
    min_cut=0.02,
    max_cut=0.3,
    stretch="power",
    power=3
)

im = axes[0].imshow(counts, origin="lower", interpolation="None")
axes[0].set_title("Counts")
plt.colorbar(im);

im = axes[1].imshow(result.components.flux_total_numpy, origin="lower", norm=norm_asinh, interpolation="bicubic")
axes[1].set_title("Deconvolved");
plt.colorbar(im);

# %%
print(calibrations)
# Out:
# NPredCalibrations
# -----------------
#
#   vela-junior-above-10GeV-data-psf0:
#
#     shift_x             : -1.718
#     shift_y             : -0.512
#     background_norm     : 0.113
#     frozen              : False
#
#   vela-junior-above-10GeV-data-psf1:
#
#     shift_x             : -0.079
#     shift_y             : -1.349
#     background_norm     : 0.270
#     frozen              : False
#
#   vela-junior-above-10GeV-data-psf2:
#
#     shift_x             : -0.050
#     shift_y             : 0.922
#     background_norm     : 0.242
#     frozen              : False
#
#   vela-junior-above-10GeV-data-psf3:
#
#     shift_x             : 0.036
#     shift_y             : 0.023
#     background_norm     : 0.222
#     frozen              : False

# %%
# could visually compare aginst https://arxiv.org/abs/2303.12686
geom = datasets["vela-junior-above-10GeV-data-psf0"]["counts"].geom.to_image()
flux = Map.from_geom(geom, data=component.flux_numpy)

geom_icrc = WcsGeom.create(
    skydir=geom.center_skydir,
    width=3 * u.deg,
    binsz=0.02
)

flux_icrs = flux.interp_to_geom(geom_icrc)

norm_pwr = simple_norm(
    flux.data,
    min_cut=0,
    max_cut=0.6,
    stretch="power",
    power=1.3,
)
flux_icrs.plot(cmap="cubehelix", norm=norm_pwr)
# Out:
# <WCSAxes: >

# %%
result.write(filename_jolideco_result, overwrite=True)
# Out:
# INFO:jolideco.utils.io.fits:writing results/vela-junior-above-10GeV-data/jolideco/vela-junior-above-10GeV-data-result-jolideco.fits

# %% [markdown]
# ## Residuals

# %%
npreds = {}

for name, dataset in datasets_jolideco.items():
    model = NPredModels.from_dataset_numpy(
        dataset=dataset,
        components=result.components,
    )
    
    fluxes = result.components.to_flux_tuple()
    npred = model.evaluate(fluxes=fluxes).detach().numpy()[0, 0]
    npreds[name] =  Map.from_geom(data=npred, geom=geom)
    

npreds_calibrated = {}

for name, dataset in datasets_jolideco.items():
    model = NPredModels.from_dataset_numpy(
        dataset=dataset,
        components=result.components,
        calibration=calibrations[name]
    )
    
    fluxes = result.components.to_flux_tuple()
    npred = model.evaluate(fluxes=fluxes).detach().numpy()[0, 0]
    npreds_calibrated[name] = Map.from_geom(data=npred, geom=geom)
# Out:
# /Users/adonath/software/mambaforge/envs/jolideco-fermi-examples/lib/python3.9/site-packages/torch/nn/functional.py:4289: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(

# %%
npred_stacked = Map.from_geom(geom=geom)

for npred in npreds_calibrated.values():
    npred_stacked.stack(npred)


npred_stacked.write(filename_npred_stacked, overwrite=True)

# %%
fig, axes = plt.subplots(
    ncols=2,
    nrows=2,
    subplot_kw={"projection": wcs},
    gridspec_kw={"wspace": 0.2},
    figsize=(12, 12)
)


for name, ax in zip_longest(datasets_jolideco, axes.flat):
    if name is None:
        ax.set_visible(False)
        continue
        
    dataset = datasets[name]
    counts = dataset["counts"].sum_over_axes(keepdims=False).smooth(5)
    npred = npreds[name].smooth(5)
    
    residual = (counts - npred) / np.sqrt(npred)
    
    residual.plot(ax=ax, vmin=-0.5, vmax=0.5, cmap="RdBu", add_cbar=True)
    ax.set_title(f"{name}")

# %%
fig, axes = plt.subplots(
    ncols=2,
    nrows=2,
    subplot_kw={"projection": wcs},
    gridspec_kw={"wspace": 0.2},
    figsize=(12, 12)
)


for name, ax in zip_longest(datasets_jolideco, axes.flat):
    if name is None:
        ax.set_visible(False)
        continue
        
    dataset = datasets[name]
    counts = dataset["counts"].sum_over_axes(keepdims=False).smooth(5)
    npred = npreds_calibrated[name].smooth(5)
    
    residual = (counts - npred) / np.sqrt(npred)
    
    residual.plot(ax=ax, vmin=-0.5, vmax=0.5, cmap="RdBu", add_cbar=True)
    ax.set_title(f"{name}")
